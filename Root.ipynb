# %%
# from pyspark.functions import col
from pyspark.sql.functions import col,lit

df = spark.sql("SELECT * FROM projectamazing.customer")
display(df)

df2 = df.withColumn("Country", lit("US"))
display(df2)

df2.write.mode("overwrite").saveAsTable("mission100ramtest.ProjectAmazingSilver.customer")

# %%
df_silver_customer = spark.sql("SELECT * FROM mission100ramtest.ProjectAmazingSilver.customer")
display(df_silver_customer)

# %%
# %sql
SELECT * FROM mission100ramtest.ProjectAmazingSilver.customer

# %%
df3 = df2.select("customer_name", "customer_state")
df3.createOrReplaceTempView("CustomerTemp")

# %%
# %sql

SELECT * FROM CustomerTemp

# %%
result_df= _sqldf.select("customer_name")
display(result_df)

# %%
silver_customer_path = "/Volumes/mission100ramtest/projectamazingsilver/projectamazingsilver/silver_customer"
df_silver_customer.write.mode("overwrite").format("delta").save(silver_customer_path)

# %%
# %fs
ls "/Volumes/mission100ramtest/projectamazingsilver/projectamazingsilver/silver_customer"

# %%
spark.read.format("delta").load(silver_customer_path).display()

# %%
from delta.tables import DeltaTable

deltaTable = DeltaTable.forName(spark, "mission100ramtest.projectamazingsilver.customer")
deltaTable.delete("customer_id = 4")

# %%
silver_states_path = "abfss://landing@azdatabrickpractice.dfs.core.windows.net/Mission100RamTest/projectamazingsilver/projectamazingsilver/STATES"
df_silver_customer.select("customer_state").write.mode("overwrite").format("delta").option("mergeSchema","true").option("path",silver_states_path).saveAsTable("mission100ramtest.projectamazingsilver.states")

# %%
df_result = spark.read.format("delta").load(silver_states_path)
display(df_result)

# %%
df_result.expalin()
